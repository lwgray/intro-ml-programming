# %% [markdown]
# # Week 5 Post-Class Exercise: Iris Clustering & PCA
#
# **Scaffolding:** 50% (you write significant code!)
# **Dataset:** Iris (150 samples, 4 features)
# **Estimated Time:** 90-120 minutes
#
# ---
#
# ## Learning Objectives
#
# By completing this exercise independently, you will:
# 1. Apply the complete unsupervised learning workflow on your own
# 2. Make decisions about K without instructor guidance
# 3. Interpret clusters based on feature analysis
# 4. Use PCA for both visualization AND preprocessing
# 5. Compare clustering results with/without PCA
#
# ---
#
# ## The Challenge
#
# You're a botanist studying iris flowers. You have measurements of 150 iris flowers:
# - Sepal length
# - Sepal width
# - Petal length
# - Petal width
#
# **Your mission:**
# 1. Find natural groupings in the data using K-Means
# 2. Visualize clusters using PCA
# 3. (BONUS) Try clustering AFTER PCA - does it change results?
#
# **Note:** The Iris dataset actually has 3 species labels, but you WON'T use them for clustering. At the end, you'll compare your clusters to the true species.
#
# ---
#
# ## Part 1: Load & Explore Data

# %%
# TODO: Import necessary libraries
# You'll need: numpy, pandas, matplotlib, seaborn
# sklearn.datasets (load_iris)
# sklearn.preprocessing (StandardScaler)
# sklearn.cluster (KMeans)
# sklearn.decomposition (PCA)
# sklearn.metrics (silhouette_score)

# YOUR CODE HERE

# %%
# TODO: Load the iris dataset
# Hint: iris = load_iris()
# Extract X (features) and feature_names

# YOUR CODE HERE

# Create a DataFrame for easier analysis
df = pd.DataFrame(X, columns=feature_names)

print(f"Dataset shape: {X.shape}")
print(f"\nFeature names: {feature_names}")
df.head()

# %%
# TODO: Check basic statistics
# Use df.describe() to see feature ranges

# YOUR CODE HERE

# %% [markdown]
# ### TODO: Answer these questions
#
# **Q1: Do features have similar scales?**
# - (Look at min/max values in describe() output)
# - YOUR ANSWER:
#
# **Q2: Why does this matter for K-Means?**
# - YOUR ANSWER:
#
# ---
#
# ## Part 2: Feature Scaling

# %%
# TODO: Scale the features using StandardScaler
# Create scaler, fit_transform X, store in X_scaled

# YOUR CODE HERE

print("✅ Features scaled")
print(f"Mean of scaled features: {X_scaled.mean(axis=0).round(2)}")
print(f"Std of scaled features: {X_scaled.std(axis=0).round(2)}")

# %% [markdown]
# ---
#
# ## Part 3: Choose Optimal K
#
# **YOUR TASK:** Implement BOTH elbow method AND silhouette analysis.

# %%
# TODO: Implement elbow method
# 1. Create empty list for inertias
# 2. Loop over K from 1 to 10
# 3. Fit KMeans for each K
# 4. Append inertia to list
# 5. Plot K vs inertia

# YOUR CODE HERE

# %%
# TODO: Implement silhouette analysis
# 1. Loop over K from 2 to 8
# 2. Fit KMeans and get labels
# 3. Calculate silhouette_score(X_scaled, labels)
# 4. Print K and score

# YOUR CODE HERE

# %% [markdown]
# ### TODO: Decide on K
#
# **Based on your analysis:**
#
# **Q3: Where is the elbow?**
# - YOUR ANSWER:
#
# **Q4: Which K has the highest silhouette score?**
# - YOUR ANSWER:
#
# **Q5: What K will you choose and why?**
# - YOUR ANSWER:
#
# ---
#
# ## Part 4: Fit K-Means

# %%
# TODO: Fit K-Means with your chosen K
# 1. Create KMeans object with your chosen n_clusters
# 2. Use random_state=42 for reproducibility
# 3. fit_predict on X_scaled
# 4. Store labels in variable 'clusters'
# 5. Add to DataFrame as 'cluster' column

K_chosen = # YOUR CHOICE HERE (e.g., 3)

# YOUR CODE HERE

print(f"✅ K-Means fitted with K={K_chosen}")
print(f"\nCluster distribution:")
print(df['cluster'].value_counts().sort_index())

# %% [markdown]
# ---
#
# ## Part 5: Interpret Clusters

# %%
# TODO: Calculate mean values for each cluster
# Use df.groupby('cluster').mean()

# YOUR CODE HERE

# %%
# TODO: Visualize cluster characteristics with a heatmap
# Use sns.heatmap() with cluster_means transposed
# Set annot=True, fmt='.2f', cmap='coolwarm'

# YOUR CODE HERE

# %% [markdown]
# ### TODO: Name Your Clusters
#
# **For each cluster, describe its defining characteristics:**
#
# **Cluster 0:**
# - Defining features:
# - Proposed name:
# - Description:
#
# **Cluster 1:**
# - Defining features:
# - Proposed name:
# - Description:
#
# **Cluster 2:** (if applicable)
# - Defining features:
# - Proposed name:
# - Description:
#
# ---
#
# ## Part 6: PCA Visualization

# %%
# TODO: Apply PCA to reduce to 2 components
# 1. Create PCA with n_components=2
# 2. fit_transform X_scaled
# 3. Store result in X_pca

# YOUR CODE HERE

print(f"PC1 variance explained: {pca.explained_variance_ratio_[0]:.1%}")
print(f"PC2 variance explained: {pca.explained_variance_ratio_[1]:.1%}")
print(f"Total variance explained: {pca.explained_variance_ratio_.sum():.1%}")

# %%
# TODO: Visualize clusters in PCA space
# Create scatter plot with:
# - x-axis: X_pca[:, 0]
# - y-axis: X_pca[:, 1]
# - color: clusters
# - Add labels showing variance explained

# YOUR CODE HERE

# %% [markdown]
# ### TODO: Analyze PCA Results
#
# **Q6: What % of total variance is explained by PC1 + PC2?**
# - YOUR ANSWER:
#
# **Q7: Are clusters well-separated in PCA space?**
# - YOUR ANSWER:
#
# **Q8: Is this % variance "good enough" for visualization?**
# - YOUR ANSWER:
#
# ---
#
# ## Part 7: BONUS - Clustering AFTER PCA
#
# **Challenge:** Try clustering in PCA space instead of original space!

# %%
# BONUS TODO: Fit K-Means on X_pca (2D PCA features)
# 1. Use same K as before
# 2. fit_predict on X_pca
# 3. Store in 'clusters_pca'

# YOUR CODE HERE

# Add to DataFrame
df['cluster_pca'] = clusters_pca

print("Cluster distribution (PCA-based):")
print(df['cluster_pca'].value_counts().sort_index())

# %%
# BONUS TODO: Compare original clusters vs PCA-based clusters
# Create a confusion matrix: pd.crosstab(df['cluster'], df['cluster_pca'])

# YOUR CODE HERE

# %% [markdown]
# ### BONUS: Reflection
#
# **Q9: Do clustering results differ when using PCA space vs original space?**
# - YOUR ANSWER:
#
# **Q10: Which approach do you prefer and why?**
# - YOUR ANSWER:
#
# ---
#
# ## Part 8: Compare with True Labels (BONUS)
#
# **Important:** This is just for learning! In real unsupervised learning, you DON'T have true labels.

# %%
# The Iris dataset has true species labels
# Let's see how our clusters compare
true_labels = iris.target
target_names = iris.target_names

df['true_species'] = true_labels

# Compare clusters to true species
comparison = pd.crosstab(df['cluster'], df['true_species'])
comparison.columns = target_names
print("\nCluster vs True Species:")
print(comparison)

# %%
# Visualize: clusters vs true labels side-by-side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Your clusters
axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', s=50, alpha=0.7, edgecolors='k')
axes[0].set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})')
axes[0].set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})')
axes[0].set_title('Your K-Means Clusters')
axes[0].grid(True, alpha=0.3)

# Plot 2: True species
axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=true_labels, cmap='viridis', s=50, alpha=0.7, edgecolors='k')
axes[1].set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})')
axes[1].set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})')
axes[1].set_title('True Species Labels')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### TODO: Final Reflection
#
# **Q11: How well do your clusters match the true species?**
# - YOUR ANSWER:
#
# **Q12: If there are differences, what might explain them?**
# - Hint: Think about what K-Means optimizes (distances) vs what defines species (biology)
# - YOUR ANSWER:
#
# **Q13: In a real-world scenario WITHOUT true labels, how would you validate your clusters?**
# - YOUR ANSWER:
#
# ---
#
# ## 🎯 Self-Assessment Checklist
#
# By completing this exercise, can you:
#
# - [ ] Load and scale data for clustering?
# - [ ] Use elbow method to guide K selection?
# - [ ] Calculate and interpret silhouette scores?
# - [ ] Fit K-Means and extract cluster labels?
# - [ ] Interpret cluster characteristics via feature means?
# - [ ] Apply PCA for dimensionality reduction?
# - [ ] Interpret variance explained ratios?
# - [ ] Visualize high-dimensional clusters in 2D?
# - [ ] Compare clustering in original vs PCA space?
# - [ ] Explain why unsupervised learning differs from supervised?
#
# **If you checked all boxes: Excellent work!** 🎉
#
# **If you struggled:** Review the solutions, then try a different dataset (e.g., digits from sklearn).
#
# ---
#
# ## 📚 What's Next?
#
# 1. **Check your work:** Compare with `week5_postclass_solutions.ipynb`
# 2. **Deepen understanding:** Try the bonus PCA preprocessing notebook
# 3. **Reflect:** Complete `Week5_Self_Assessment.md`
# 4. **Get ready:** Week 6 covers Neural Networks!
#
# ---
#
# **Great job working through Week 5! Unsupervised learning is challenging - you're making excellent progress! 🚀**
