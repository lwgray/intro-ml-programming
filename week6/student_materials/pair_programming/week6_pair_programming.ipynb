# %% [markdown]
# # Week 6: Pair Programming - Network Architects
#
# **Exercise:** Experiment with neural network architectures
# **Time:** 15 minutes
# **Scaffolding:** 60% provided (guided experimentation)
# **Partners:** Work in pairs!
#
# ---
#
# ## 🎯 Your Mission
#
# You've seen a working MNIST classifier. Now **experiment**!
#
# **Your tasks:**
# 1. Run the baseline model (provided)
# 2. Experiment 1: Add a third hidden layer
# 3. Experiment 2: Remove a hidden layer
# 4. Experiment 3: Change neuron counts
# 5. Compare results!
#
# **Key:** **Predict → Run → Discuss** with your partner!
#
# ---

# %% [markdown]
# ## Setup (Provided)

# %%
import os
os.environ['KERAS_BACKEND'] = 'torch'
import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt

# Load and normalize MNIST
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0

print("✓ Data loaded and normalized")

# %% [markdown]
# ---
#
# ## Baseline Model (Run This First!)

# %%
# Baseline: 2 hidden layers (128, 64)
baseline_model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

baseline_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Baseline architecture:")
baseline_model.summary()

# %%
# Train baseline (5 epochs for speed)
print("\nTraining baseline model...")
baseline_history = baseline_model.fit(
    X_train, y_train,
    epochs=5,
    validation_split=0.2,
    verbose=1
)

# Evaluate
baseline_test_loss, baseline_test_acc = baseline_model.evaluate(X_test, y_test, verbose=0)
print(f"\nBaseline test accuracy: {baseline_test_acc:.4f}")

# %% [markdown]
# **Baseline results:** ~97-98% accuracy
#
# **Now let's experiment!**
#
# ---

# %% [markdown]
# ## Experiment 1: Add a Third Hidden Layer
#
# **Question to discuss with partner:** Will adding more layers improve accuracy? Why or why not?
#
# **TODO:** Modify the model to have 3 hidden layers instead of 2

# %%
# TODO: Build model with 3 hidden layers
# Suggested architecture: 128 → 64 → 32 → 10
# Fill in the missing layer!

experiment1_model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    # TODO: Add third hidden layer with 32 neurons, ReLU activation
    layers.Dense(____, activation='____'),
    layers.Dense(10, activation='softmax')
])

experiment1_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Experiment 1 architecture:")
experiment1_model.summary()

# %%
# Train experiment 1
print("\nTraining experiment 1...")
exp1_history = experiment1_model.fit(
    X_train, y_train,
    epochs=5,
    validation_split=0.2,
    verbose=1
)

exp1_test_loss, exp1_test_acc = experiment1_model.evaluate(X_test, y_test, verbose=0)
print(f"\nExperiment 1 test accuracy: {exp1_test_acc:.4f}")
print(f"Change from baseline: {exp1_test_acc - baseline_test_acc:+.4f}")

# %% [markdown]
# **Discuss with partner:**
# - Did accuracy improve?
# - Did training take longer?
# - Why might a deeper network help (or not help)?
#
# ---

# %% [markdown]
# ## Experiment 2: Remove a Hidden Layer
#
# **Question:** Will a simpler network (1 hidden layer) still work well?
#
# **TODO:** Build model with only 1 hidden layer

# %%
# TODO: Build model with 1 hidden layer
# Suggested: 128 neurons → 10 outputs

experiment2_model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    # TODO: Add ONE hidden layer with 128 neurons, ReLU
    layers.Dense(____, activation='____'),
    layers.Dense(10, activation='softmax')
])

experiment2_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

experiment2_model.summary()

# %%
# Train experiment 2
print("\nTraining experiment 2...")
exp2_history = experiment2_model.fit(
    X_train, y_train,
    epochs=5,
    validation_split=0.2,
    verbose=1
)

exp2_test_loss, exp2_test_acc = experiment2_model.evaluate(X_test, y_test, verbose=0)
print(f"\nExperiment 2 test accuracy: {exp2_test_acc:.4f}")
print(f"Change from baseline: {exp2_test_acc - baseline_test_acc:+.4f}")

# %% [markdown]
# **Discuss:**
# - How does 1 layer compare to 2 layers?
# - Is simpler always worse?
# - What's the tradeoff?
#
# ---

# %% [markdown]
# ## Experiment 3: Change Network Width
#
# **Question:** Will more neurons per layer help?
#
# **TODO:** Try wider layers (256, 128)

# %%
# TODO: Build model with wider layers
# Try: 256 → 128 → 10

experiment3_model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    # TODO: First layer with 256 neurons
    layers.Dense(____, activation='____'),
    # TODO: Second layer with 128 neurons
    layers.Dense(____, activation='____'),
    layers.Dense(10, activation='softmax')
])

experiment3_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

experiment3_model.summary()

# %%
# Train experiment 3
print("\nTraining experiment 3...")
exp3_history = experiment3_model.fit(
    X_train, y_train,
    epochs=5,
    validation_split=0.2,
    verbose=1
)

exp3_test_loss, exp3_test_acc = experiment3_model.evaluate(X_test, y_test, verbose=0)
print(f"\nExperiment 3 test accuracy: {exp3_test_acc:.4f}")
print(f"Change from baseline: {exp3_test_acc - baseline_test_acc:+.4f}")

# %% [markdown]
# **Discuss:**
# - Does doubling neurons double accuracy?
# - What's the cost of more neurons?
# - Diminishing returns?
#
# ---

# %% [markdown]
# ## Results Summary
#
# **Fill in your results:**

# %%
import pandas as pd

results = pd.DataFrame({
    'Experiment': ['Baseline (2 layers)', '3 layers', '1 layer', 'Wider (256,128)'],
    'Test Accuracy': [
        f"{baseline_test_acc:.4f}",
        f"{exp1_test_acc:.4f}",
        f"{exp2_test_acc:.4f}",
        f"{exp3_test_acc:.4f}"
    ],
    'Parameters': [
        baseline_model.count_params(),
        experiment1_model.count_params(),
        experiment2_model.count_params(),
        experiment3_model.count_params()
    ]
})

print(results)

# %% [markdown]
# ---
#
# ## 🎓 Key Insights
#
# **What did you learn?**
#
# 1. Deeper vs. shallower networks: ______________________________________
#
# 2. More neurons vs. fewer: _____________________________________________
#
# 3. Best architecture for MNIST: ________________________________________
#
# 4. Tradeoffs: __________________________________________________________
#
# **Biggest surprise:** ___________________________________________________
#
# ---
#
# ## 🚀 Bonus (If Time)
#
# **Try different activations:**
# - Change ReLU to 'tanh' in hidden layers
# - Does it still work?
# - Better or worse?
#
# **Or:**
# - Train for 10 epochs instead of 5
# - Does accuracy continue improving?
#
# ---
#
# *Great work experimenting! These patterns transfer to ANY neural network problem.*
#
# *Last Updated: 2026-02-02*
