# %% [markdown]
# # Week 7: Post-Class Exercise
#
# **Assignment:** Build production-ready Fashion-MNIST classifier
# **Estimated Time:** 45-60 minutes
# **Scaffolding:** 50% provided (build from scratch)
# **Due:** Before Week 8
#
# ---
#
# ## Learning Objectives
#
# Apply all Week 7 concepts independently:
# 1. Three-way data split (train/validation/test)
# 2. Build model with Dropout regularization
# 3. Train with EarlyStopping callback
# 4. Plot and interpret training curves
# 5. Evaluate final model and save
#
# ---
#
# ## Instructions
#
# Follow the TODOs to build your classifier. Test your understanding by working independently before checking solutions.
#
# **Grading:**
# - Model trains successfully: 40%
# - Uses Dropout and EarlyStopping: 30%
# - Plots training curves: 15%
# - Test accuracy > 85%: 15%
#
# ---

# %% [markdown]
# ## Part 1: Setup and Data Loading

# %%
# Setup (provided)
import os
os.environ['KERAS_BACKEND'] = 'torch'

import keras
from keras import layers
from keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

print(f"Keras version: {keras.__version__}")
print("Setup complete!")

# %%
# TODO: Load Fashion-MNIST dataset
# HINT: from keras.datasets import fashion_mnist
#       fashion_mnist.load_data() returns ((X_train, y_train), (X_test, y_test))

from keras.datasets import ____

(X_train_full, y_train_full), (X_test, y_test) = ____.load_data()

print(f"Full training set: {X_train_full.shape}")
print(f"Test set: {X_test.shape}")

# %% [markdown]
# ### Task 1: Normalize Data
#
# Scale pixel values to 0-1 range

# %%
# TODO: Normalize pixel values by dividing by 255.0

X_train_full = ____
X_test = ____

print(f"After normalization:")
print(f"Training range: {X_train_full.min():.2f} to {X_train_full.max():.2f}")
print(f"Test range: {X_test.min():.2f} to {X_test.max():.2f}")

# %% [markdown]
# ### Task 2: Three-Way Split
#
# Split training data into train and validation sets (80/20 split)

# %%
# TODO: Use train_test_split to create train and validation sets
# HINT: test_size=0.2 for 20% validation, random_state=42 for reproducibility

X_train, X_val, y_train, y_val = train_test_split(
    ____, ____,
    test_size=____,
    random_state=____
)

print(f"Training set: {X_train.shape}")
print(f"Validation set: {X_val.shape}")
print(f"Test set: {X_test.shape}")

# %% [markdown]
# ### Task 3: Flatten Data
#
# Reshape images from (28, 28) to (784,) for Dense layers

# %%
# TODO: Flatten all three sets using .reshape(-1, 784)

X_train_flat = ____
X_val_flat = ____
X_test_flat = ____

print(f"Flattened training: {X_train_flat.shape}")
print(f"Flattened validation: {X_val_flat.shape}")
print(f"Flattened test: {X_test_flat.shape}")

# %% [markdown]
# ---
#
# ## Part 2: Build Model with Dropout
#
# **Requirements:**
# - Input layer: 784 neurons
# - Hidden layer 1: 128 neurons, ReLU activation
# - Dropout: 0.3 rate
# - Hidden layer 2: 64 neurons, ReLU activation
# - Dropout: 0.3 rate
# - Output layer: 10 neurons, softmax activation

# %%
# TODO: Build Sequential model with architecture above
# HINT: Use layers.Input(), layers.Dense(), layers.Dropout()

model = keras.Sequential([
    # TODO: Input layer (784 features)
    layers.Input(shape=(____,)),
    
    # TODO: First Dense layer (128 neurons, relu)
    layers.Dense(____, activation='____'),
    
    # TODO: First Dropout (0.3 rate)
    layers.Dropout(____),
    
    # TODO: Second Dense layer (64 neurons, relu)
    layers.Dense(____, activation='____'),
    
    # TODO: Second Dropout (0.3 rate)
    layers.Dropout(____),
    
    # TODO: Output layer (10 classes, softmax)
    layers.Dense(____, activation='____')
])

print("Model architecture:")
model.summary()

# %% [markdown]
# ### Task 4: Compile Model

# %%
# TODO: Compile model
# optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']

model.compile(
    optimizer='____',
    loss='____',
    metrics=['____']
)

print("Model compiled!")

# %% [markdown]
# ---
#
# ## Part 3: Configure EarlyStopping
#
# **Requirements:**
# - Monitor: validation loss
# - Patience: 5 epochs
# - Restore best weights: Yes
# - Verbose: 1

# %%
# TODO: Create EarlyStopping callback

early_stop = EarlyStopping(
    monitor='____',           # Watch val_loss
    patience=____,            # Wait 5 epochs
    restore_best_weights=____, # True
    verbose=____              # 1
)

print("EarlyStopping configured!")

# %% [markdown]
# ---
#
# ## Part 4: Train Model
#
# Train with validation data and EarlyStopping callback

# %%
# TODO: Train model
# REQUIREMENTS:
# - Training data: X_train_flat, y_train
# - validation_data: (X_val_flat, y_val)
# - epochs: 50 (EarlyStopping will stop us)
# - batch_size: 128
# - callbacks: [early_stop]

print("Training model with regularization...")
history = model.fit(
    ____, ____,
    validation_data=(____, ____),
    epochs=____,
    batch_size=____,
    callbacks=[____],
    verbose=1
)

print("\nTraining complete!")

# %% [markdown]
# ---
#
# ## Part 5: Plot Training Curves
#
# Create side-by-side plots of loss and accuracy

# %%
# TODO: Plot training and validation curves

plt.figure(figsize=(12, 4))

# Loss plot
plt.subplot(1, 2, 1)
# TODO: Plot training loss and validation loss
plt.plot(history.history['____'], label='Training Loss', linewidth=2)
plt.plot(history.history['____'], label='Validation Loss', linewidth=2)

plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
plt.title('Loss Over Time')
plt.grid(True, alpha=0.3)

# Accuracy plot
plt.subplot(1, 2, 2)
# TODO: Plot training accuracy and validation accuracy
plt.plot(history.history['____'], label='Training Accuracy', linewidth=2)
plt.plot(history.history['____'], label='Validation Accuracy', linewidth=2)

plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.title('Accuracy Over Time')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print final training performance
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]
print(f"\nFinal Training Accuracy: {train_acc:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")
print(f"Gap: {(train_acc - val_acc):.4f}")

# %% [markdown]
# ### Reflection: Analyze Your Curves
#
# **Answer these questions:**
#
# 1. **Which Training Curves Pattern do you see?**
#    - [ ] Healthy Learning (both decreasing, close together)
#    - [ ] Beginning to Overfit (small gap opening)
#    - [ ] Severe Overfitting (large gap)
#    - [ ] Underfitting (both high)
#
# 2. **Did EarlyStopping trigger? At what epoch?**
#    - Answer: _________________________________________________
#
# 3. **Is the gap between train/val accuracy < 0.05?**
#    - Answer: _________________________________________________
#
# ---

# %% [markdown]
# ## Part 6: Final Evaluation on Test Set

# %%
# TODO: Evaluate model on test set
# HINT: model.evaluate(X_test_flat, y_test)

test_loss, test_accuracy = model.evaluate(____, ____, verbose=0)

print(f"\nFinal Test Results:")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")

# Compare to validation
print(f"\nValidation Accuracy: {val_acc:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Difference: {abs(val_acc - test_accuracy):.4f}")

if test_accuracy >= 0.85:
    print("\nSUCCESS! Test accuracy >= 85%")
else:
    print("\nTest accuracy < 85%. Try: more epochs, different architecture, or adjust dropout.")

# %% [markdown]
# ---
#
# ## Part 7: Save Model

# %%
# TODO: Save model to 'week7_fashion_mnist.keras'

model.save('____')
print("Model saved!")

# Verify loading works
from keras.models import load_model
loaded_model = load_model('week7_fashion_mnist.keras')
print("Model loaded successfully!")

# Test prediction
sample_prediction = loaded_model.predict(X_test_flat[:1], verbose=0)
print(f"\nSample prediction shape: {sample_prediction.shape}")
print(f"Predicted class: {np.argmax(sample_prediction[0])}")
print(f"Actual class: {y_test[0]}")

# %% [markdown]
# ---
#
# ## Part 8: Bonus Visualizations (Optional)
#
# Visualize some predictions

# %%
# Bonus: Visualize predictions (provided)
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Get predictions for first 10 test images
predictions = model.predict(X_test_flat[:10], verbose=0)
predicted_classes = np.argmax(predictions, axis=1)

plt.figure(figsize=(15, 3))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[i], cmap='gray')
    
    # Color: green if correct, red if wrong
    color = 'green' if predicted_classes[i] == y_test[i] else 'red'
    plt.title(f"Pred: {class_names[predicted_classes[i]]}\nTrue: {class_names[y_test[i]]}",
              color=color, fontsize=9)
    plt.axis('off')

plt.tight_layout()
plt.show()

# Calculate accuracy for these 10
correct = np.sum(predicted_classes == y_test[:10])
print(f"\nCorrect predictions: {correct}/10")

# %% [markdown]
# ---
#
# ## Self-Assessment Checklist
#
# **Before submitting, verify:**
#
# - [ ] Three-way split implemented correctly (train/val/test)
# - [ ] Model includes Dropout layers after each Dense layer
# - [ ] EarlyStopping callback configured properly
# - [ ] Model trained with validation_data and callbacks
# - [ ] Training curves plotted (loss and accuracy)
# - [ ] Test accuracy calculated
# - [ ] Model saved successfully
# - [ ] Code runs without errors from top to bottom
#
# **Expected Results:**
# - Test accuracy: 85-89%
# - Training stopped early (before epoch 50)
# - Small gap between train/val accuracy (< 0.05)
#
# ---
#
# ## Extension Challenges (Optional)
#
# 1. **Architecture Experiment:** Try 256→128→64 architecture. Does it improve?
# 2. **Dropout Tuning:** Try rates 0.2, 0.4, 0.5. Which is best?
# 3. **Patience Experiment:** Try patience=3 and patience=10. What changes?
# 4. **Compare to No Regularization:** Train same model without Dropout/EarlyStopping. How much does regularization help?
#
# ---
#
# ## Submission
#
# **Submit:**
# 1. This completed notebook (.ipynb file)
# 2. Your saved model file (week7_fashion_mnist.keras)
#
# **Due:** Before Week 8 live session
#
# **Questions?** Post in #week7-homework channel
#
# ---
#
# *Week 7 Post-Class Exercise | Version 1.0 | February 2026*
